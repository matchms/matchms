# %% [markdown]
# # Spec2Vec - test ability to match unkown spectra to similar ones

# %%
# Locations
ROOT = "C:\\OneDrive - Netherlands eScience Center\\Project_Wageningen_iOMEGA"
PATH_SPEC2VEC = ROOT + "\\Spec2Vec\\code\\"
PATH_MS_DATA = ROOT + "\\Data\\GNPS_all\\"
PATH_SAVE_MODEL = ROOT + "\\Spec2Vec\\models_trained\\"
PATH_COMPUTED = ROOT + "\\Spec2Vec\\computed_results\\"
PATH_OUTPUT = ROOT + "\\Spec2Vec\\output_plots\\"

# %%
import numpy as np
import sys
sys.path.insert(0, PATH_SPEC2VEC)

# %%
import helper_functions as functions
import MS_functions
import MS_similarity_classical as MS_sim_classic
from similarity_measure import SimilarityMeasures
from plotting_functions import plot_precentile

from scipy import spatial

# %% [markdown]
# ### Load filtered allGNPS_positive dataset OR:  Import& filter allGNPS_positive dataset

# %%
file_json = PATH_MS_DATA + "allGNPS_positive_minmax_10_1000_2dec_exp08_191115.json"
file_mgf = ROOT + "\\Data\\GNPS_all\\" + "allGNPS_positive_191106.mgf"

spectra, spectra_dict, MS_documents, MS_documents_intensity, spectra_metadata = MS_functions.load_MGF_data(file_mgf = file_mgf,
                                                           file_json = file_json,
                                                           num_decimals = 2,
                                                           min_frag = 0.0, max_frag = 1000.0,
                                                           min_loss = 5.0, max_loss = 500.0,
                                                           min_intensity_perc = 0,
                                                           exp_intensity_filter = 0.8,
                                                           min_keep_peaks_0 = 10,
                                                           min_keep_peaks_per_mz = 20/200,
                                                           min_peaks = 10,
                                                           max_peaks = 1000,
                                                           peak_loss_words = ['peak_', 'loss_'])
# Out:
# Spectra json file found and loaded.

# %%
spectra_metadata.head()
# Out:
#    doc_ID             gnps_ID                           name title  \
# 0       0  CCMSLIB00005435503  chenodeoxycholic acid M-H2O+H   NaN
# 1       1  CCMSLIB00005435504     chenodeoxycholic acid 2M+H   NaN
# 2       2  CCMSLIB00005435505    chenodeoxycholic acid 2M+Na   NaN
# 3       3  CCMSLIB00005435506               cholic acid M+Na   NaN
# 4       4  CCMSLIB00005435507       deoxycholic acid M-H2O+H   NaN
#
#    precursor_mz  num_peaks_losses  \
# 0       375.290                93
# 1       785.593               101
# 2       807.575                21
# 3       431.277                35
# 4       375.289               157
#
#                                                inchi  \
# 0  "InChI=1S/C24H40O4/c1-14(4-7-21(27)28)17-5-6-1...
# 1  "InChI=1S/C24H40O4/c1-14(4-7-21(27)28)17-5-6-1...
# 2  "InChI=1S/C24H40O4/c1-14(4-7-21(27)28)17-5-6-1...
# 3  "InChI=1S/C24H40O5/c1-13(4-7-21(28)29)16-5-6-1...
# 4  "InChI=1S/C24H40O4/c1-14(4-9-22(27)28)18-7-8-1...
#
#                       inchikey  \
# 0  RUDATBOHQWOJDD-GYHJSIKNSA-N
# 1  RUDATBOHQWOJDD-PODLAYBOSA-N
# 2  RUDATBOHQWOJDD-PODLAYBOSA-N
# 3  BHQCQFFYRZLCQQ-IHELEQLESA-N
# 4  KXGVEGMKQFWNSR-BKAWJTANSA-N
#
#                                               smiles  charge
# 0  C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3...       1
# 1  C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3...       1
# 2  C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3...       1
# 3  C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1([C@H](C[...       1
# 4  C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1([C@H](C[...       1

# %% [markdown]
# ### Get metadata from benchmarking subset

# %%
file_json = PATH_MS_DATA + "uniqueInchikey_positive_minmax_10_1000_2dec_exp08_191116.json"
file_mgf = []

_,_,_,_, spectra_metadata_uniqueinchikey_positive = MS_functions.load_MGF_data(file_mgf = file_mgf,
                                                           file_json = file_json,
                                                           num_decimals = 2,
                                                           min_frag = 0.0, max_frag = 1000.0,
                                                           min_loss = 5.0, max_loss = 500.0,
                                                           min_intensity_perc = 0.0, #0.1,
                                                           exp_intensity_filter = 0.8,
                                                           min_keep_peaks_0 = 10,
                                                           min_keep_peaks_per_mz = 20/200,
                                                           min_peaks = 10,
                                                           max_peaks = 1000, #None, #500,
                                                           peak_loss_words = ['peak_', 'loss_'])
# Out:
# Spectra json file found and loaded.

# %%
benchmarking_gnpsIDs = spectra_metadata_uniqueinchikey_positive['gnps_ID'].values.copy()
benchmarking_gnpsIDs.shape
# Out:
# (10998,)

# %%
benchmarking_gnpsIDs[:10]
# Out:
# array(['CCMSLIB00005435506', 'CCMSLIB00005435507', 'CCMSLIB00005435517',
#        'CCMSLIB00005435523', 'CCMSLIB00005435528', 'CCMSLIB00005435529',
#        'CCMSLIB00005435532', 'CCMSLIB00005435537', 'CCMSLIB00005435545',
#        'CCMSLIB00005435547'], dtype=object)

# %% [markdown]
# ### Shuffle gnps IDs

# %%
np.random.seed(42) # to make it reproducible
np.random.shuffle(benchmarking_gnpsIDs)

# %%
benchmarking_gnpsIDs[:10]
# Out:
# array(['CCMSLIB00000579646', 'CCMSLIB00000850303', 'CCMSLIB00000856170',
#        'CCMSLIB00000845612', 'CCMSLIB00000079847', 'CCMSLIB00000845821',
#        'CCMSLIB00000079739', 'CCMSLIB00000854639', 'CCMSLIB00000846422',
#        'CCMSLIB00000205344'], dtype=object)

# %%
all_gnpsIDs = spectra_metadata['gnps_ID'].values
all_gnpsIDs.shape
# Out:
# (90226,)

# %%
remove_parts = [0, 250, 500, 1000, 2000, 5000, 10998]

for i, remove_part in enumerate(remove_parts):
    print("Run", i, 20 * '--')
    # Remove some benchmarking spectra from corpus
    MS_documents_removedpart = [MS_documents[x] for x in range(len(MS_documents)) if all_gnpsIDs[x] not in benchmarking_gnpsIDs[:remove_part]]   
    print("Modified corpus consists of", len(MS_documents_removedpart), "documents.")
    
    MS_measure = SimilarityMeasures(MS_documents_removedpart)
    MS_measure.preprocess_documents(1, min_frequency = 2, create_stopwords = False)
    print("Number of unique words: ", len(MS_measure.dictionary))
    
    # Train new model based on reduced corpus
    file_model_word2vec = PATH_SAVE_MODEL + 'S2V_allGNPS_pos_removed' + str(remove_part) + '_d300_w500_neg5_minmax10_1000_dec2_exp08.model'
    MS_measure.build_model_word2vec(file_model_word2vec, sg=0, negative=5, size=300, window=500, 
                                 min_count=1, workers=4, iterations= [10,5], 
                                 use_stored_model=True)
    print("Learning rate droped from", MS_measure.model_word2vec.alpha, "to", MS_measure.model_word2vec.min_alpha_yet_reached)
# Out:
# Run 0 ----------------------------------------
# Modified corpus consists of 90226 documents.
# Preprocess documents...
# Number of unique words:  145584
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 7042434.0
#  Epoch 2 of 15.Change in loss after epoch 2: 5072664.0
#  Epoch 3 of 15.Change in loss after epoch 3: 4562966.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3656586.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3622282.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3383436.0
#  Epoch 7 of 15.Change in loss after epoch 7: 3347842.0
#  Epoch 8 of 15.Change in loss after epoch 8: 3019338.0
#  Epoch 9 of 15.Change in loss after epoch 9: 1972052.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1846808.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed0_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1874012.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1812516.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1796916.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1746648.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1756180.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed0_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.02125085341254184
# Run 1 ----------------------------------------
# Modified corpus consists of 89976 documents.
# Preprocess documents...
# Number of unique words:  145583
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 6946716.5
#  Epoch 2 of 15.Change in loss after epoch 2: 4999381.5
#  Epoch 3 of 15.Change in loss after epoch 3: 4643885.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3723089.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3534922.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3426474.0
#  Epoch 7 of 15.Change in loss after epoch 7: 3363250.0
#  Epoch 8 of 15.Change in loss after epoch 8: 3076566.0
#  Epoch 9 of 15.Change in loss after epoch 9: 1947324.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1947424.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed250_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1862328.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1767772.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1857044.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1802392.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1741448.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed250_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.02125076409264693
# Run 2 ----------------------------------------
# Modified corpus consists of 89726 documents.
# Preprocess documents...
# Number of unique words:  145579
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 6807660.0
#  Epoch 2 of 15.Change in loss after epoch 2: 4787264.0
#  Epoch 3 of 15.Change in loss after epoch 3: 4585774.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3735042.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3567896.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3488654.0
#  Epoch 7 of 15.Change in loss after epoch 7: 3282488.0
#  Epoch 8 of 15.Change in loss after epoch 8: 3132622.0
#  Epoch 9 of 15.Change in loss after epoch 9: 1985856.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1903868.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed500_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1838496.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1828800.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1799344.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1738380.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1739212.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed500_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.02125075786282683
# Run 3 ----------------------------------------
# Modified corpus consists of 89226 documents.
# Preprocess documents...
# Number of unique words:  145578
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 6869205.5
#  Epoch 2 of 15.Change in loss after epoch 2: 5004864.5
#  Epoch 3 of 15.Change in loss after epoch 3: 4629523.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3664853.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3425168.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3423820.0
#  Epoch 7 of 15.Change in loss after epoch 7: 3251010.0
#  Epoch 8 of 15.Change in loss after epoch 8: 3178044.0
#  Epoch 9 of 15.Change in loss after epoch 9: 1935628.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1848880.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed1000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1817240.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1757396.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1750572.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1746720.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1740092.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed1000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.021250734090960035
# Run 4 ----------------------------------------
# Modified corpus consists of 88226 documents.
# Preprocess documents...
# Number of unique words:  145572
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 6555402.0
#  Epoch 2 of 15.Change in loss after epoch 2: 4922279.0
#  Epoch 3 of 15.Change in loss after epoch 3: 4454807.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3651068.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3425986.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3339542.0
#  Epoch 7 of 15.Change in loss after epoch 7: 3066366.0
#  Epoch 8 of 15.Change in loss after epoch 8: 3084750.0
#  Epoch 9 of 15.Change in loss after epoch 9: 2279884.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1773160.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed2000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1799744.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1768080.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1652856.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1646164.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1674508.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed2000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.021250427878403193
# Run 5 ----------------------------------------
# Modified corpus consists of 85226 documents.
# Preprocess documents...
# Number of unique words:  145546
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 6565356.0
#  Epoch 2 of 15.Change in loss after epoch 2: 4628799.0
#  Epoch 3 of 15.Change in loss after epoch 3: 4160274.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3496437.0
#  Epoch 5 of 15.Change in loss after epoch 5: 3213510.0
#  Epoch 6 of 15.Change in loss after epoch 6: 3149740.0
#  Epoch 7 of 15.Change in loss after epoch 7: 2851400.0
#  Epoch 8 of 15.Change in loss after epoch 8: 2841286.0
#  Epoch 9 of 15.Change in loss after epoch 9: 2723382.0
#  Epoch 10 of 15.Change in loss after epoch 10: 1657664.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed5000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1632552.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1599740.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1594932.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1554652.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1538556.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed5000_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.021250662943233287
# Run 6 ----------------------------------------
# Modified corpus consists of 79228 documents.
# Preprocess documents...
# Number of unique words:  145429
# No saved word2vec model found with given filename!
# Calculating new word2vec model...
#  Epoch 1 of 15.Change in loss after epoch 1: 5716471.5
#  Epoch 2 of 15.Change in loss after epoch 2: 4242625.5
#  Epoch 3 of 15.Change in loss after epoch 3: 3652479.0
#  Epoch 4 of 15.Change in loss after epoch 4: 3484566.0
#  Epoch 5 of 15.Change in loss after epoch 5: 2787646.0
#  Epoch 6 of 15.Change in loss after epoch 6: 2690114.0
#  Epoch 7 of 15.Change in loss after epoch 7: 2633254.0
#  Epoch 8 of 15.Change in loss after epoch 8: 2473356.0
#  Epoch 9 of 15.Change in loss after epoch 9: 2447450.0
#  Epoch 10 of 15.Change in loss after epoch 10: 2291436.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed10998_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model
#  Epoch 11 of 15.Change in loss after epoch 11: 1747430.0
#  Epoch 12 of 15.Change in loss after epoch 12: 1344332.0
#  Epoch 13 of 15.Change in loss after epoch 13: 1316420.0
#  Epoch 14 of 15.Change in loss after epoch 14: 1291672.0
#  Epoch 15 of 15.Change in loss after epoch 15: 1267748.0
# Saving model with name: C:\OneDrive - Netherlands eScience Center\Project_Wageningen_iOMEGA\Spec2Vec\models_trained\S2V_allGNPS_pos_removed10998_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_15.model
# Learning rate droped from 0.025 to 0.021250567981016814

# %%
def get_similarities_removed_parts(A_ref, 
                                   remove_parts, 
                                   filenames, 
                                   save_matrix, 
                                   save_refscore):
    # Run routine for all saved models
    ref_score_Spec2Vec_tests_lst = []
    for i, filename in enumerate(filenames):
        print("Run", i, 20 * '--')
        MS_measure.build_model_word2vec(filename, size=300, window=500, 
                                 min_count=1, workers=4, iterations=1, 
                                 use_stored_model=True)

        MS_measure.get_vectors_centroid(method = 'ignore', #'update',
                                 extra_weights = MS_documents_intensity, 
                                 tfidf_weighted = False,
                                 weight_method = 'sqrt', 
                                 tfidf_model = None,
                                 extra_epochs = 5)

        M_sim_ctr = 1 - spatial.distance.cdist(MS_measure.vectors_centroid, MS_measure.vectors_centroid, 'cosine')
        np.save(save_matrix + str(remove_parts[i]) + '_191120.npy', M_sim_ctr)

        A = np.delete(np.delete(M_sim_ctr, exclude_IDs, axis = 0), exclude_IDs, axis = 1)
        A = np.delete(A.reshape(length**2), remove_diagonal)

        # Plot against dice score on morgan3 fingerprints   
        ref_score_Spec2Vec = plot_precentile(A, A_ref, num_bins = 1000 , show_top_percentile = 0.5)
        ref_score_Spec2Vec_tests_lst.append(ref_score_Spec2Vec)
        np.save(save_refscore + str(remove_parts[i]) + '_morgan3_dice.npy', ref_score_Spec2Vec) 
        
    return ref_score_Spec2Vec_tests_lst

# %% [markdown]
# ### Import benchmarking subset (uniqueInchikey_positive dataset)

# %%
file_json = PATH_MS_DATA + "uniqueInchikey_positive_minmax_10_1000_2dec_exp08_191116.json"
file_mgf = ROOT + "\\Data\\GNPS_all\\" + "allGNPS_positive_uniqueInchikey_191107.mgf"

spectra, spectra_dict, MS_documents, MS_documents_intensity, sub_spectra_metadata = MS_functions.load_MGF_data(file_mgf = file_mgf,
                                                           file_json = file_json,
                                                           num_decimals = 2,
                                                           min_frag = 0.0, max_frag = 1000.0,
                                                           min_loss = 5.0, max_loss = 500.0,
                                                           min_intensity_perc = 0.0, #0.1,
                                                           exp_intensity_filter = 0.8,
                                                           min_keep_peaks_0 = 10,
                                                           min_keep_peaks_per_mz = 20/200,
                                                           min_peaks = 10,
                                                           max_peaks = 1000, #None, #500,
                                                           peak_loss_words = ['peak_', 'loss_'])
# Out:
# Spectra json file found and loaded.

# %%
MS_measure = SimilarityMeasures(MS_documents)
MS_measure.preprocess_documents(1, min_frequency = 2, create_stopwords = False)
print("Number of unique words: ", len(MS_measure.dictionary))
# Out:
# Preprocess documents...
# Number of unique words:  116344

# %% [markdown]
# ### Import reference similarity scores (based on molecular fingerprints)

# %%
filename = PATH_COMPUTED + 'MS_sim_mol_uniqueInchikey_morgan3_dice2048_191119.npy'
M_sim_mol = MS_sim_classic.mol_sim_matrix([], #fingerprints_morgan3_2048,
                                       [], #fingerprints_morgan3_2048,
                                       method = 'dice',
                                       filename = filename)
# Out:
# Molecular similarity scores found and loaded.

# %%
# Find bette way to keep track of wrong fingerprints!!
exclude_IDs = [1435, 1440, 2232, 2233, 9384, 10791, 10991]

# %%
# Transform molecular similarity matrix in 1D array AND remove all excluded IDs
A_ref = np.delete(np.delete(M_sim_mol, exclude_IDs, axis = 0), exclude_IDs, axis = 1)
length = A_ref.shape[0]
remove_diagonal = np.array([(i*length + i) for i in range(length)])
A_ref = np.delete(A_ref.reshape(length**2), remove_diagonal)

# %% [markdown]
# ### Import reference score (modified cosine)

# %%
ref_score_cum_modcos_minmatch14 = np.load(PATH_COMPUTED + 'spec2vec_uniquesmiles_pos_ModCos_min_match_14.npy')

# %%
remove_parts = [0, 250, 500, 1000, 2000, 5000, 10998]

filenames = []
for remove_part in remove_parts:   
    # Load model trained on reduced corpus
    filenames.append(PATH_SAVE_MODEL + 'S2V_allGNPS_pos_removed' + str(remove_part) + '_d300_w500_neg5_minmax10_1000_dec2_exp08_iter_10.model')
    
ref_score_Spec2Vec_tests_lst = get_similarities_removed_parts(A_ref,
                                        remove_parts,
                                        filenames, 
                                        save_matrix = PATH_COMPUTED + 'M_sim_allGNPS_pos_d300_w500_minmax10_1000_dec2_exp08_iter_10_removed', 
                                        save_refscore = PATH_COMPUTED + 'ref_score_allGNPS_pos_d300_w500_minmax10_1000_dec2_exp08_iter_10_removed')
# Out:
# Load stored word2vec model ...
# All 'words' of the given documents were found in the trained word2vec model.
#   Calculated centroid vectors for  10998  of  10998  documents.of  10998  documents. 10998  documents.520  of  10998  documents. Calculated centroid vectors for  570  of  10998  documents. 10998  documents.10998  documents.  documents. documents. 10998  documents.  documents. 10998  documents. 10998  documents. of  10998  documents.5470  of  10998  documents. documents. of  10998  documents.6400  of  10998  documents. 10998  documents. 10998  documents.  of  10998  documents.  documents.10998  documents. 10998  documents.  of  10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 1  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.00  of  10998  documents. of  10998  documents.1860  of  10998  documents.2120  of  10998  documents.  documents. 10998  documents.  documents.  of  10998  documents. of  10998  documents. documents.10998  documents.  documents. of  10998  documents.  of  10998  documents. 10998  documents. Calculated centroid vectors for  6850  of  10998  documents.7020  of  10998  documents. 10998  documents.8270  of  10998  documents.10998  documents. 10998  documents.10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 2  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.0  of  10998  documents.500  of  10998  documents.1550  of  10998  documents.1740  of  10998  documents. 2570  of  10998  documents.3960  of  10998  documents. 10998  documents. Calculated centroid vectors for  5150  of  10998  documents. 5500  of  10998  documents. 10998  documents. of  10998  documents.  documents.5700  of  10998  documents. 6640  of  10998  documents. of  10998  documents. 10998  documents. of  10998  documents.  of  10998  documents. 10998  documents.8690  of  10998  documents.8800  of  10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 2  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.of  10998  documents.  documents. 10998  documents. of  10998  documents.2690  of  10998  documents.3160  of  10998  documents. 10998  documents.  of  10998  documents.3610  of  10998  documents.  documents. 10998  documents.10998  documents. of  10998  documents. 10998  documents. 5660  of  10998  documents. 10998  documents.  of  10998  documents.10998  documents.  documents.8280  of  10998  documents. 10998  documents. of  10998  documents.10540  of  10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 4  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.of  10998  documents.2440  of  10998  documents. 10998  documents.  of  10998  documents. of  10998  documents.  of  10998  documents. of  10998  documents. of  10998  documents.  of  10998  documents.10998  documents. 10998  documents. of  10998  documents. of  10998  documents. documents. of  10998  documents.  of  10998  documents.  of  10998  documents.  documents. 10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 20  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.of  10998  documents. 10998  documents.3090  of  10998  documents. of  10998  documents. Calculated centroid vectors for  4490  of  10998  documents. of  10998  documents. 10998  documents.5430  of  10998  documents. 5670  of  10998  documents. Calculated centroid vectors for  6810  of  10998  documents. of  10998  documents.7510  of  10998  documents.  of  10998  documents. 10998  documents. documents.  documents. 10998  documents.10620  of  10998  documents. 10998  documents. of  10998  documents.Load stored word2vec model ...
# Not all 'words' of the given documents are present in the trained word2vec model!
# 98  out of  116344  'words' were not found in the word2vec model.
# 'Words'missing in the pretrained word2vec model will be ignored.
# Removing missing 'words' from corpus...
#   Calculated centroid vectors for  10998  of  10998  documents.0998  documents.1320  of  10998  documents.  documents.  of  10998  documents. 10998  documents.  documents. documents.4370  of  10998  documents. of  10998  documents. Calculated centroid vectors for  5280  of  10998  documents.6230  of  10998  documents.  documents. documents. of  10998  documents.  of  10998  documents. 10998  documents.7850  of  10998  documents.10230  of  10998  documents.10640  of  10998  documents.

# %% [markdown]
# ## Plot results

# %%
from matplotlib import pyplot as plt
import matplotlib

# Compare all:
num_bins = 1000
show_top_percentile = 0.5

plt.style.use('ggplot') # ('default')
fig, ax = plt.subplots(figsize=(12,10))
cmap = matplotlib.cm.get_cmap('inferno') #'viridis') 

selectedpairs = [(x, remove_parts[x]) for x in [0,2,4,5,6]] #range(len(remove_parts))]
count = 1

for i, remove_part in selectedpairs:
    plt.plot((show_top_percentile/num_bins*(1+np.arange(num_bins)))[::-1], ref_score_Spec2Vec_tests_lst[i], 
             color= cmap(i/8), 
             label= str(count) + ') Spec2Vec - Model: allGNPS (' + str(remove_part) + ' spectra removed) \n (minmax=(10, 1000),  exp0.8 filter, iter=15, dim=300)')
    count += 1

plt.plot((show_top_percentile/num_bins*(1+np.arange(num_bins)))[::-1], ref_score_cum_modcos_minmatch14, 
         ':', color='crimson', #'gold', #'crimson',
         label= str(count) + ') Modified cosine score (tol = 0.005, min_match = 14)')

plt.legend(fontsize=12)
plt.title('Mean molecular similarity for best scoring spectral similarities')
plt.xlabel("Top percentile of spectral similarity score g(s,s')", fontsize=14)
plt.ylabel("Mean molecular similarity (f(t,t') within that percentile)", fontsize=14)
ax.set_xticks([0,0.02,0.04,0.06, 0.08, 0.1])
ax.set_xticklabels(['0%','0.02%','0.04%','0.06%','0.08%', '0.1%'])
ax.tick_params(direction='out', labelsize=14)
plt.xlim(0, 0.1)
plt.ylim(0.26, 0.76)

plt.savefig(PATH_OUTPUT + 'Top_percentile_testing_removing_spectra_191120.pdf')

# %% [markdown]
# ## Note:
# ### Issue with repdroducibility was: Gensim has a weird learning-rate decay!
# In gensim the default learning-rate (alpha) is set to 0.025 and it will linearly decay to a default of min_alpha = 0.0001.
# This is independent of the number of epochs (iter), which lead to unexpected results!
# A model trained on 10 iterations only will look very different than a model after 10 iterations which was started with iter=100.
